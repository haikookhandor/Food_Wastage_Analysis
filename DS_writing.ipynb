# %% [markdown]
# ## Introduction

# %% [markdown]
# The aim of this project is to study the mess food wastage of IIT Gandhinagar, analyze the food wasting habits and suggest remedies to reduce food wastage.By analyzing the amount of food wasted, we can gain insights into the patterns and habits of food wastage. Additionally, we conducted a Google form survey with the students to understand their perspectives on the issue. Based on our analysis, we suggest remedies to reduce food wastage, *TO BE FILLED*.Our ultimate goal is to help the mess hall in IIT Gandhinagar become more sustainable and reduce its environmental impact while also saving costs.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset

# %% [markdown]
# Our data was collected from the food wastage log book at Jaiswal Dining Hall for the years 2019 and 2020. The data was manually recorded in the form of a PDF containing photos of the log book. We extracted the data from the PDF and entered it into an Excel sheet for analysis.
# During our initial analysis of the data, we discovered that there were missing months in the dataset. We addressed this issue by replacing the missing values with zeros. Additionally, there were some missing data points for specific meals on certain days. We took the average of the days around the same to account for it. We also collected mess menus from the mess secretary, seniors, and the data provided in the assignment. These menus were used to correlate the food served at the mess with the amount of food wastage. In our analysis wrt food items, we have considered the mess menu and wastage data from July 2019 - December 2020 with the missing month as April 2020 in between. For seasonal analysis, we consider the entire wastage data from Jan-2019 to December-2020.

# %% [markdown]
# ## Seasonal trends: (2019)

# %% [markdown]
# The following chart shows the food wastage during the year 2019 for breakfast, lunch, snacks, dinner and total wastage. Each vertical black line corresponds to the end of the months of the year 2019. In 2020, due to Covid Pandemic, we did not perform the season trend analysis.

# %%
mess_wastage = pd.read_csv('mess_wastage_2019.csv')
mess_wastage.head()

# %% [markdown]
# **Breakfast**

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Convert the 'Date' column to a datetime object
mess_wastage['Date'] = pd.to_datetime(mess_wastage['Date'], format='%m-%d-%y')

# Set the x-axis to display the months
fig, ax = plt.subplots(figsize=(20,10))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

# Plot the data
ax.plot(mess_wastage['Date'], mess_wastage['Breakfast'], color='red')
ax.set_title('Breakfast wastage vs dates of 2019', fontsize=14)
ax.set_xlabel('Months', fontsize=14)
ax.set_ylabel('Breakfast wastage (in KG)', fontsize=14)
ax.grid(True)

# Add vertical lines at the end of each month
# for month in range(1, 13):
#     ax.axvline(mess_wastage[mess_wastage['Date'].dt.month == month]['Date'].max(), color='black')

plt.show()

# %% [markdown]
# Observations:
# 1. Food wastage is comparatively less in May, June, July, and December due to summer and winter breaks.
# 2. Sudden drop in food wastage in the middle 1st and 2nd semester, in the starting of March and September due to Mid-semester break.
# 3. Food wastage during winter, October, November, January is greater as compared to summer, March, April, August, September.
# 4. Students do breakfast more in winters resulting in more wastage.

# %% [markdown]
# **Lunch**

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Convert the 'Date' column to a datetime object
mess_wastage['Date'] = pd.to_datetime(mess_wastage['Date'], format='%m-%d-%y')

# Set the x-axis to display the months
fig, ax = plt.subplots(figsize=(20,10))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

# Plot the data
ax.plot(mess_wastage['Date'], mess_wastage['Lunch'], color='blue')
ax.set_title('Lunch wastage vs dates of 2019', fontsize=14)
ax.set_xlabel('Months', fontsize=14)
ax.set_ylabel('Lunch wastage', fontsize=14)
ax.grid(True)

# Add vertical lines at the end of each month
# for month in range(1, 13):
#     ax.axvline(mess_wastage[mess_wastage['Date'].dt.month == month]['Date'].max(), color='black')

plt.show()

# %% [markdown]
# Observations:
# 1. Food wastage during 1st semester is more than the wastage during 2nd semester.
# 2. Students prefer to have lunch more after winter break as compared to after summer break. This leads to more wastage of food.

# %% [markdown]
# **Snacks**

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Convert the 'Date' column to a datetime object
mess_wastage['Date'] = pd.to_datetime(mess_wastage['Date'], format='%m-%d-%y')

# Set the x-axis to display the months
fig, ax = plt.subplots(figsize=(20,10))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

# Plot the data
ax.plot(mess_wastage['Date'], mess_wastage['Snacks'], color='green')
ax.set_title('Snacks wastage vs dates of 2019', fontsize=14)
ax.set_xlabel('Months', fontsize=14)
ax.set_ylabel('Snacks wastage (in KG)', fontsize=14)
ax.grid(True)

# Add vertical lines at the end of each month
# for month in range(1, 13):
#     ax.axvline(mess_wastage[mess_wastage['Date'].dt.month == month]['Date'].max(), color='black')

plt.show()

# %% [markdown]
# Observations:
# 1. Similar wastage  throughout the semesters.
# 2. Students do love having snacks throughout the year irrespective of the season.
# 3. Continuous ups and downs are the same for both semesters.
# 4. Food wastage on some days is almost half than the previous day suggesting that students like some snacks more than the other.

# %% [markdown]
# **Dinner**

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Convert the 'Date' column to a datetime object
mess_wastage['Date'] = pd.to_datetime(mess_wastage['Date'], format='%m-%d-%y')

# Set the x-axis to display the months
fig, ax = plt.subplots(figsize=(20,10))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

# Plot the data
ax.plot(mess_wastage['Date'], mess_wastage['Dinner'], color='orange')
ax.set_title('Dinner wastage vs dates of 2019', fontsize=14)
ax.set_xlabel('Months', fontsize=14)
ax.set_ylabel('Dinner wastage (in KG)', fontsize=14)
ax.grid(True)

# Add vertical lines at the end of each month
# for month in range(1, 13):
#     ax.axvline(mess_wastage[mess_wastage['Date'].dt.month == month]['Date'].max(), color='black')

plt.show()

# %% [markdown]
# Observations:
# 1. Food wastage during 1st semester is more than the wastage during 2nd semester.
# 2. Students prefer to have lunch more after winter break as compared to after summer break. This leads to more wastage of food.
# 3. The food wastage distribution of dinner is almost the same as the food wastage distribution of lunch.
# 4. It suggests that students have both lunch and dinner with the same frequency.

# %% [markdown]
# **Total**

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Convert the 'Date' column to a datetime object
mess_wastage['Date'] = pd.to_datetime(mess_wastage['Date'], format='%m-%d-%y')

# Set the x-axis to display the months
fig, ax = plt.subplots(figsize=(20,10))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

# Plot the data
ax.plot(mess_wastage['Date'], mess_wastage['Total'], color='violet')
ax.set_title('Total wastage vs dates of 2019', fontsize=14)
ax.set_xlabel('Months', fontsize=14)
ax.set_ylabel('Total wastage (in KG)', fontsize=14)
ax.grid(True)

# Add vertical lines at the end of each month
# for month in range(1, 13):
#     ax.axvline(mess_wastage[mess_wastage['Date'].dt.month == month]['Date'].max(), color='black')

plt.show()

# %% [markdown]
# Observations:
#
# 1. Food wastage is less in summer, winter and mid semester break.
# 2. The food wastage is more after winter break as compared to summer break because of more student preference.
# 3. The continuous ups and downs suggest that there is a particular liking towards some food as compared to the other.
# 4. The food wastage distribution of dinner is almost the same as the food wastage distribution of lunch. It suggests that students have both lunch and dinner with the same frequency. Students prefer lunch and dinner over breakfast and snacks.

# %% [markdown]
# ## Observations from survey

# %% [markdown]
# To gain additional insights into the food preferences of students at the mess, we conducted a survey using a Google Form. The survey asked questions about how often students ate breakfast, lunch, snacks, and dinner at the mess, as well as their preferred food items.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Breakfast**: <br>
# 0-10 days: 46.7% <br>
# 10-20 days: 17.3% <br>
# 20-30 days: 36% <br>
# This suggests that breakfast is less popular than lunch and dinner at the<br> mess, with a higher percentage of students having breakfast at the mess less frequently.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Lunch**: <br>
# 0-10 days: 22.7%<br>
# 10-20 days: 29.3%<br>
# 20-30 days: 48%<br>
# This suggests that lunch is quite popular at the mess, with nearly half of the students having lunch at the mess almost every day.

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# **Snacks**: <br>
# 0-10 days - 33.33% <br>
# 10-20 days - 33.33% <br>
# 20-30 days - 33.33% <br>
# This suggests that snacks are evenly distributed among the three frequency ranges.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Dinner**: <br>
# 0-10 days - 10.7% <br>
# 10-20 days - 37.3% <br>
# 20-30 days - 52% <br>
# This suggests that dinner is the most popular meal at the mess, with over half of the students having dinner at the mess almost every day.

# %% [markdown]
# From the data, it seems that dinner is the most popular meal at the mess, with 52% of students having dinner at the mess for 20-30 days. Lunch is the second most popular meal at the mess, with 48% of students having lunch at the mess for 20-30 days. Breakfast and snacks seem to be less popular, with a higher percentage of students having these meals at the mess for 0-10 days.
#
#
# Some other patterns and information that can be inferred from the data include:
# - The percentage of students having breakfast for 20-30 days is higher than that of lunch for 20-30 days.
# - The percentage of students having dinner for 20-30 days is higher than any other meal for 20-30 days.
# - The percentage of students who have snacks at the mess is evenly distributed among the three frequency ranges.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Based on the data, it seems that
#
# - Paneer Vegetable dishes (Tikka, Bhurjee, Palak, Shahi, etc.) are the most popular among students, with 69.3% of students preferring this option.
# - South Indian dishes (Idli, Dosa, Vada) are also quite popular, with 62.7% of students preferring this option.
# - Cabbage Masala is the least popular option among students, with only 13.3% of students preferring this dish.
#
# This information can be useful in planning the menu for the mess and reducing food wastage by offering more of the popular dishes and less of the less popular ones.

# %%
# Load the data
data= pd.read_csv('Mess_wastage_data.csv')

# %%
df = data[(data['Date']>='07-01-19')]

# %%
# Group the DataFrame by category
df_grouped = {}
df_grouped['Breakfast'] = df[['Date', 'Menu item Breakfast', 'Wastage Breakfast']]
df_grouped['Lunch'] = df[['Date', 'Menu item Lunch', 'Wastage Lunch']]
df_grouped['Snacks'] = df[['Date', 'Menu item Snacks', 'Wastage Snacks']]
df_grouped['Dinner'] = df[['Date', 'Menu item Dinner', 'Wastage Dinner']]

# %% [markdown]
# ## Hot-Favorite Dishes V/s Time:

# %% [markdown]
# We floated a google form to identify the hot favorite dishes among the community.We then analyze the food wastage over time when these dishes were served in the mess in different meals.

# %% [markdown]
# Directions for use:
# 1. Select any meal.
# 2. Select the corresponding food item.
# 3. Click on Display Plot.

# %%
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output
# import ipywidgets as widgets

# Define update function
def update_plot(category, menu_item):
    group = df_grouped[category].loc[df_grouped[category][f'Menu item {category}'] == menu_item]
    plt.clf()
    sns.set_style('whitegrid')
    sns.set_palette('pastel')
    ax = plt.axes()
    ax.set_facecolor("#f2f2f2")
    if len(group['Date']) // 10 > 1:
        sns.set(rc={'figure.figsize':(10,6)})
        sns.lineplot(x=group['Date'], y=group[f'Wastage {category}'], linewidth = 2, color ='#FF0000' )
        plt.title(menu_item, fontsize=16)
        plt.xlabel('Time', fontsize=14)
        plt.ylabel(category, fontsize=14)
        plt.xticks(group['Date'][::len(group['Date'])//10], group['Date'][::len(group['Date'])//10], rotation=45)
        plt.grid(True)
        plt.show()
    elif len(group['Date'])//5 >1:
        sns.set(rc={'figure.figsize':(10,6)})
        sns.lineplot(x=group['Date'], y=group[f'Wastage {category}'], linewidth = 2, color ='#FF0000')
        plt.title(menu_item, fontsize=16)
        plt.xlabel('Time', fontsize=14)
        plt.ylabel(category, fontsize=14)
        plt.xticks(group['Date'][::len(group['Date'])//5], group['Date'][::len(group['Date'])//5], rotation=45)
        plt.grid(True)
        plt.show()
    else:
        sns.set(rc={'figure.figsize':(10,6)})
        sns.lineplot(x=group['Date'], y=group[f'Wastage {category}'], linewidth = 2, color ='#FF0000')
        plt.title(menu_item, fontsize=16)
        plt.xlabel('Time', fontsize=14)
        plt.ylabel(category, fontsize=14)
        plt.xticks(group['Date'], group['Date'], rotation=45)
        plt.grid(True)
        plt.show()

# Create dropdown widget to select category
category_dropdown = widgets.Dropdown(options=['Breakfast', 'Lunch', 'Snacks', ])

# Create a nested dictionary of radio buttons for each category
menu_items = {}
for category in category_dropdown.options:
    menu_items[category] = widgets.RadioButtons(options=df_grouped[category][f"Menu item {category}"].unique())

# Create a container to hold the radio buttons
menu_items_container = widgets.VBox()

# Display radio buttons for selected category
def update_menu_items(change):
    category = change.new
    menu_items_container.children = [menu_items[category]]

category_dropdown.observe(update_menu_items, names='value')

# Create an output area to display the plot
output = widgets.Output()
display(output)


# Display plot for selected category and menu item
def on_button_clicked(b):
    category = category_dropdown.value
    menu_item = menu_items_container.children[0].value
    with output:
        clear_output(wait=True)
        update_plot(category, menu_item)

# Create button to display plot
display_button = widgets.Button(description="Display plot")
display_button.on_click(on_button_clicked)

# Display widgets
display(category_dropdown)
display(menu_items_container)
display(display_button)
# Out:
# Output()
# Dropdown(options=('Breakfast', 'Lunch', 'Snacks', 'Dinner'), value='Breakfast')
# VBox()
# Button(description='Display plot', style=ButtonStyle())

# %% [markdown]
# ## Histogram of Wastage V/s Days:

# %% [markdown]
# **Breakfast**

# %%
sns.histplot(df['Wastage Breakfast']) # Histogram of food waste
plt.ylabel('Number of Days')
plt.xlabel('Wastage in Breakfast')
# Out:
# Text(0.5, 0, 'Wastage in Breakfast')

# %% [markdown]
# **Lunch**

# %%
sns.histplot(df['Wastage Lunch']) # Histogram of food waste
plt.ylabel('Number of Days')
plt.xlabel('Wastage in Lunch')
# Out:
# Text(0.5, 0, 'Wastage in Lunch')

# %% [markdown]
# **Snacks**

# %%
sns.histplot(df['Wastage Snacks']) # Histogram of food waste
plt.ylabel('Number of Days')
plt.xlabel('Wastage in Snacks')
# Out:
# Text(0.5, 0, 'Wastage in Snacks')

# %% [markdown]
# **Dinner**

# %%
sns.histplot(df['Wastage Dinner']) # Histogram of food waste
plt.ylabel('Number of Days')
plt.xlabel('Wastage in Dinner')
# Out:
# Text(0.5, 0, 'Wastage in Dinner')

# %% [markdown]
# ## Average Food Waste

# %% [markdown]
# We show the average food wastage across different meals for a particular menu item in the below plots.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the data by Main dish and calculate the mean breakfast waste for each group
df_grouped = df.groupby('Menu item Breakfast')['Wastage Breakfast'].mean()

# Plot the bar plot using seaborn
sns.set_style("whitegrid")
sns.set_palette("bright")
sns.set_context("talk", font_scale=0.8)
sns.barplot(x=df_grouped.index, y=df_grouped.values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Menu Item')
plt.ylabel('Average Breakfast Waste')
plt.title('Average Breakfast Waste by Main Dish')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the data by Main dish and calculate the mean breakfast waste for each group
df_grouped = df.groupby('Menu item Lunch')['Wastage Lunch'].mean()

# Plot the bar plot using seaborn
sns.set(rc={'figure.figsize':(10,6)})
sns.set_style("whitegrid")
sns.set_palette("bright")
sns.set_context("talk", font_scale=0.8)
sns.barplot(x=df_grouped.index, y=df_grouped.values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Menu Item')
plt.ylabel('Average Lunch Waste')
plt.title('Average Lunch Waste by Main Dish')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the data by Main dish and calculate the mean breakfast waste for each group
df_grouped = df.groupby('Menu item Snacks')['Wastage Snacks'].mean()

# Plot the bar plot using seaborn
sns.set(rc={'figure.figsize':(10,6)})
sns.set_style("whitegrid")
sns.set_palette("bright")
sns.set_context("talk", font_scale=0.8)
sns.barplot(x=df_grouped.index, y=df_grouped.values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Menu Item')
plt.ylabel('Average Snacks Waste')
plt.title('Average Snacks Waste by Main Dish')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the data by Main dish and calculate the mean breakfast waste for each group
df_grouped = df.groupby('Menu item Dinner')['Wastage Dinner'].mean()

# Plot the bar plot using seaborn
sns.set(rc={'figure.figsize':(10,6)})
sns.set_style("whitegrid")
sns.set_palette("bright")
sns.set_context("talk", font_scale=0.8)
sns.barplot(x=df_grouped.index, y=df_grouped.values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Menu Item')
plt.ylabel('Average Dinner Waste')
plt.title('Average Dinner Waste by Main Dish')
plt.tight_layout()
plt.show()

# %% [markdown]
# We can infer that Khamani is the most wasted item in the Breakfast, Mixed veg in the Lunch and Noodles (Chinese food) in the Dinner.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
from scipy.stats import ttest_ind

# %%
df = pd.read_csv('wastage.csv')

# %%
def weekend_analyse(df, wastage):
  df['day_of_week'] = pd.to_datetime(df['Date']).dt.weekday
  df['day_type'] = df['day_of_week'].apply(lambda x: 'weekend' if x >= 5 else 'weekday')
  
  grouped = df.groupby('day_type')[wastage].sum()
  total_weekdays = df[df['day_type'] == 'weekday']['day_type'].count()
  total_weekends = df[df['day_type'] == 'weekend']['day_type'].count()

  weekday_data = df[df['day_type'] == 'weekday'][wastage]
  weekend_data = df[df['day_type'] == 'weekend'][wastage]

  weekday_mean = weekday_data.mean()
  weekday_std = weekday_data.std()

  weekend_mean = weekend_data.mean()
  weekend_std = weekend_data.std()
  return weekday_mean, weekday_std, weekend_mean, weekend_std, total_weekdays, total_weekends, grouped

# %%
def plot_analyse(grouped, meal):
  grouped.plot(kind='bar')
  plt.title(f'{meal} wasted on Weekends vs. Weekdays')
  plt.xlabel('Day Type')
  plt.ylabel('Amount Wasted')
  plt.show()

# %%
def plot_confident(df, wastage,meal):
  weekday_data = df[df['day_type'] == 'weekday'][wastage]
  weekend_data = df[df['day_type'] == 'weekend'][wastage]

  # set the parameters for the normal curve
  mu = weekday_data.mean()
  sigma = weekday_data.std()

  # create the x-axis
  x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

  # calculate the y-axis values for the normal curve
  y = stats.norm.pdf(x, mu, sigma)

  # set the confidence level
  conf_level = 0.95

  # calculate the critical value based on the confidence level
  crit_val = stats.norm.ppf(1 - ((1 - conf_level)/2))

  # calculate the margin of error
  margin_err = crit_val * (sigma)

  # calculate the upper and lower limits of the confidence interval
  upper_lim = mu + margin_err
  lower_lim = mu - margin_err

  # plot the normal curve
  plt.plot(x, y)

  # plot the confidence interval as a shaded region
  plt.fill_between(x, 0, y, where=((x >= lower_lim) & (x <= upper_lim)), color='gray', alpha=0.4)

  # plot the point on the curve corresponding to a particular x value
  plt.plot(weekend_data.mean(), stats.norm.pdf(weekend_data.mean(), mu, sigma), 'ro',label = f"Avg wastage (weekend): {round(weekend_data.mean(),2)}")

  # add labels and title to the plot
  plt.xlabel('Wastage')
  plt.legend()
  plt.ylabel('Probability Density')
  plt.title(f'95% CI for Avg {meal} wastage (weekdays) μ: {round(mu,2)}, σ: {round(sigma,2)}')
  plt.show()

# %%
df_breakfast = df[['Date', 'Menu item Breakfast','Menu item2 Breakfast','Wastage Breakfast']]
df_lunch = df[['Date', 'Menu item Lunch','Menu item2 Lunch','Wastage Lunch']]
df_snack = df[['Date', 'Menu item Snacks','Wastage Snacks']]
df_dinner = df[['Date', 'Menu item Dinner','Menu item2 Dinner','Wastage Dinner']]

# %%
weekday_mean_bf, weekday_std_bf, weekend_mean_bf, weekend_std_bf, total_weekdays, total_weekends, grouped_bf = weekend_analyse(df_breakfast, 'Wastage Breakfast')

grouped_bf['weekday'] /= total_weekdays
grouped_bf['weekend'] /= total_weekends
# plot_analyse(grouped_bf,"Breakfast")
plot_confident(df_breakfast, 'Wastage Breakfast',"Breakfast")
# Out:
# C:\Users\Haikoo\AppData\Local\Temp\ipykernel_13576\1003509622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_week'] = pd.to_datetime(df['Date']).dt.weekday
# C:\Users\Haikoo\AppData\Local\Temp\ipykernel_13576\1003509622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_type'] = df['day_of_week'].apply(lambda x: 'weekend' if x >= 5 else 'weekday')

# %%
weekday_mean_l, weekday_std_l, weekend_mean_l, weekend_std_l, total_weekdays, total_weekends, grouped_l = weekend_analyse(df_lunch, 'Wastage Lunch')

grouped_l['weekday'] /= total_weekdays
grouped_l['weekend'] /= total_weekends
# plot_analyse(grouped_l,"Lunch")
plot_confident(df_lunch, 'Wastage Lunch',"Lunch")
# Out:
# C:\Users\Haikoo\AppData\Local\Temp\ipykernel_13576\1003509622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_week'] = pd.to_datetime(df['Date']).dt.weekday
# C:\Users\Haikoo\AppData\Local\Temp\ipykernel_13576\1003509622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_type'] = df['day_of_week'].apply(lambda x: 'weekend' if x >= 5 else 'weekday')

# %%
weekday_mean_s, weekday_std_s, weekend_mean_s, weekend_std_s, total_weekdays, total_weekends, grouped_s = weekend_analyse(df_snack, 'Wastage Snacks')

grouped_s['weekday'] /= total_weekdays
grouped_s['weekend'] /= total_weekends
# plot_analyse(grouped_s,"Snacks")
plot_confident(df_snack, 'Wastage Snacks',"Snacks")
# Out:
# C:\Users\Haikoo\AppData\Local\Temp\ipykernel_13576\1003509622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_week'] = pd.to_datetime(df['Date']).dt.weekday
# C:\Users\Haikoo\AppData\Local\Temp\ipykernel_13576\1003509622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_type'] = df['day_of_week'].apply(lambda x: 'weekend' if x >= 5 else 'weekday')

# %%
weekday_mean_d, weekday_std_d, weekend_mean_d, weekend_std_d, total_weekdays, total_weekends, grouped_d = weekend_analyse(df_dinner, 'Wastage Dinner')

grouped_d['weekday'] /= total_weekdays
grouped_d['weekend'] /= total_weekends
# plot_analyse(grouped_d,"Dinner")
plot_confident(df_dinner, 'Wastage Dinner',"Dinner")
# Out:
# C:\Users\Haikoo\AppData\Local\Temp\ipykernel_13576\1003509622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_week'] = pd.to_datetime(df['Date']).dt.weekday
# C:\Users\Haikoo\AppData\Local\Temp\ipykernel_13576\1003509622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_type'] = df['day_of_week'].apply(lambda x: 'weekend' if x >= 5 else 'weekday')

# %% [markdown]
# ### PValue based Hypothesis testing for Breakfast, Lunch, Snacks, Dinner

# %% [markdown]
# **Null Hypothesis:** There is no significant difference in the breakfast wastage between the weekdays and weekends
#
# **Alternate Hypothesis:** There is significant difference in the breakfast wastage between the weekdays and weekends

# %%
weekday_data = df_breakfast.loc[df_breakfast['day_type'] == 'weekday', 'Wastage Breakfast']
weekend_data = df_breakfast.loc[df_breakfast['day_type'] == 'weekend', 'Wastage Breakfast']

t_stat, p_val = ttest_ind(weekday_data, weekend_data)

# probability of observing a test static assuming the null hypothesis is true
if p_val < 0.05:
    print('Reject null hypothesis')
else:
    print('May or may not accept null hypothesis')
# Out:
# May or may not accept null hypothesis

# %% [markdown]
# **Null Hypothesis:** There is no significant difference in the Lunch wastage between the weekdays and weekends
#
# **Alternate Hypothesis:** There is significant difference in the Lunch wastage between the weekdays and weekends

# %%
weekday_data = df_lunch.loc[df_lunch['day_type'] == 'weekday', 'Wastage Lunch']
weekend_data = df_lunch.loc[df_lunch['day_type'] == 'weekend', 'Wastage Lunch']

t_stat, p_val = ttest_ind(weekday_data, weekend_data)

# probability of observing a test static assuming the null hypothesis is true
if p_val < 0.05:
    print('Reject null hypothesis')
else:
    print('May or may not accept null hypothesis')
# Out:
# May or may not accept null hypothesis

# %% [markdown]
# **Null Hypothesis:** There is no significant difference in the Snacks wastage between the weekdays and weekends
#
# **Alternate Hypothesis:** There is significant difference in the Snacks wastage between the weekdays and weekends

# %%
weekday_data = df_snack.loc[df_snack['day_type'] == 'weekday', 'Wastage Snacks']
weekend_data = df_snack.loc[df_snack['day_type'] == 'weekend', 'Wastage Snacks']

t_stat, p_val = ttest_ind(weekday_data, weekend_data)

# probability of observing a test static assuming the null hypothesis is true
if p_val < 0.05:
    print('Reject null hypothesis')
else:
    print('May or may not accept null hypothesis')
# Out:
# May or may not accept null hypothesis

# %% [markdown]
# **Null Hypothesis:** There is no significant difference in the Dinner wastage between the weekdays and weekends
#
# **Alternate Hypothesis:** There is significant difference in the Dinner wastage between the weekdays and weekends

# %%
weekday_data = df_dinner.loc[df_dinner['day_type'] == 'weekday', 'Wastage Dinner']
weekend_data = df_dinner.loc[df_dinner['day_type'] == 'weekend', 'Wastage Dinner']

t_stat, p_val = ttest_ind(weekday_data, weekend_data)

# probability of observing a test static assuming the null hypothesis is true
if p_val < 0.05:
    print('Reject null hypothesis')
else:
    print('May or may not accept null hypothesis')
# Out:
# May or may not accept null hypothesis
